# %% [markdown]
# # Notebook to transform labels in a Yolo configuration

# %% [markdown]
# ## Import useful modules

# %%
# General modules
import os
import subprocess
import shutil
import random

# Data manipulation modules
import pandas as pd
import json
from sklearn.model_selection import train_test_split

# Image and video modules
from PIL import Image
from plotly import express as px
import cv2

# Machine learning module
from ultralytics import YOLO
# Out:
# /Users/stephane_branly/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ## Launch `label-studio` to label images

# %%
os.environ["LABEL_STUDIO_LOCAL_FILES_SERVING_ENABLED"] = "true"
os.environ["LABEL_STUDIO_LOCAL_FILES_DOCUMENT_ROOT"] = os.getcwd()

subprocess.run("label-studio")

# %% [markdown]
# ## Read `label-studio` labels file and available classes

# %%
with open("./assets/labels.json", encoding="utf-8") as f:
    annotations = json.load(f)

classes = pd.read_csv("./assets/classes.csv", names=["_"])["_"].to_list()

# %% [markdown]
# ## Display dataset images

# %%
def generate_image(annotation):
    path = "/".join(annotation["image"].split("/")[-2:])
    path = path.replace("?d=", "")
    path = path.replace("%28", "(")
    path = path.replace("%29", ")")
    path = path.replace("?d=", "")
    fig = px.imshow(Image.open(path))
    for label in annotation.get("label", []):
        x = round(label["x"] / 100 * label["original_width"])
        y = round(label["y"] / 100 * label["original_height"])
        width = round(label["width"] / 100 * label["original_width"])
        height = round(label["height"] / 100 * label["original_height"])
        str_label = label["rectanglelabels"][0]
        fig.add_shape(
            type="rect",
            x0=x,
            x1=x + width,
            y0=y,
            y1=y + height,
            xref="x",
            yref="y",
            line_color="red",
        )
        fig.add_annotation(
            x=x,
            y=y,
            text=str_label,
            xref="x",
            xanchor="left",
            yref="y",
            yanchor="bottom",
            showarrow=False,
            font_color="white",
            bgcolor="red",
        )
    return fig

# %% [markdown]
# _Run the next cell to explore randomly your dataset_

# %%
fig = generate_image(random.choice(annotations))

fig.update_layout(margin=dict(l=20, r=20, t=20, b=20), width=640, height=500)

# %% [markdown]
# ## Check the label distribution

# %%
count = {}
for annotation in annotations:
    for l in annotation.get("label", []):
        k = l["rectanglelabels"][0]
        count[k] = count.get(k, 0) + 1

# %%
fig = px.bar(
    x=classes,
    y=[count[c] for c in classes],
    color=[c.split(" ")[0] for c in classes],
)
fig.update_layout(
    xaxis={"dtick": classes},
    xaxis_title=None,
    yaxis_title="Annotation count",
    legend_title="Suit",
)

# %% [markdown]
# ## Generate Yolo annotation file

# %%
def generate_yolo_annotations(annotations):
    for a in annotations:
        path = a["image"].split("/")[-1]
        path = path.replace("?d=", "")
        path = path.replace("%28", "(")
        path = path.replace("%29", ")")
        path = path.replace("?d=", "")
        with open(f"labels/{path[:-3]}txt", mode="w", encoding="utf8") as f:
            for l in a.get("label", []):
                x_min = l["x"] / 100
                y_min = l["y"] / 100
                box_width = l["width"] / 100
                box_height = l["height"] / 100
                x_center = x_min + box_width / 2
                y_center = y_min + box_height / 2
                label = classes.index(l["rectanglelabels"][0])
                f.write(
                    f"{label} {x_center:.3f} {y_center:.3f} {box_width:.3f} {box_height:.3f}\n"
                )

# %%
# !mkdir labels

# %%
generate_yolo_annotations(annotations)

# %% [markdown]
# ## Split dataset into train, valid and test dataset

# %%
# Read images and annotations
images = [
    os.path.join("dataset", x)
    for x in os.listdir("dataset")
    if x[-3:] == "jpg"
    if x[:-3] in [y[:-3] for y in os.listdir("labels")]
]
labels = [os.path.join("labels", x) for x in os.listdir("labels") if x[-3:] == "txt"]

images.sort()
labels.sort()

# Split the dataset into train-valid-test splits
train_images, val_images, train_labels, val_labels = train_test_split(
    images, labels, test_size=0.2, random_state=1
)
val_images, test_images, val_labels, test_labels = train_test_split(
    val_images, val_labels, test_size=0.5, random_state=1
)

# %% [markdown]
# ### Create directories to move images and labels

# %%
# !mkdir images images/train images/val images/test labels/train labels/val labels/test

# %% [markdown]
# ### Move files in directories

# %%
# Utility function to move images
def move_files_to_folder(list_of_files, destination_folder, move=False):
    for f in list_of_files:
        try:
            if move:
                shutil.move(f, destination_folder)
            else:
                shutil.copy(f, destination_folder)
        except:
            print(f)
            assert False


# Copy the images into their folders
move_files_to_folder(train_images, "images/train")
move_files_to_folder(val_images, "images/val/")
move_files_to_folder(test_images, "images/test/")
# Move the labels into their folders
move_files_to_folder(train_labels, "labels/train/", move=True)
move_files_to_folder(val_labels, "labels/val/", move=True)
move_files_to_folder(test_labels, "labels/test/", move=True)

# %% [markdown]
# # Train

# %%
import os

# %%
os.environ["WANDB_DISABLED"] = "true"
model = YOLO("runs/detect/train6/weights/last.pt")
# model = YOLO("yolov8n.pt")

model.train(
    data="tarot_card_data.yaml", epochs=100, imgsz=640, device="mps", resume=True
)

# %% [markdown]
# ## Valid

# %%
# Load a model
from ultralytics import YOLO

model = YOLO("./runs/detect/train6/weights/last.pt")

# Customize validation settings
validation_results = model.val(
    data="tarot_card_data.yaml", imgsz=640, batch=16, conf=0.5, iou=0.7, device="mps"
)
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.6 torch-2.2.1 MPS (Apple M3 Pro)
# Model summary (fused): 168 layers, 3134342 parameters, 0 gradients, 8.7 GFLOPs
# val: Scanning /Users/stephane_branly/Documents/Projets/FrenchTarot/card-recognition-model/labels/val.cache... 122 images, 0 backgrounds, 0 corrupt: 100%|██████████| 122/122 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:03<00:00,  2.17it/s]
#                    all        122        163      0.823      0.731      0.814      0.776
#            diamond ace        122          2        0.5        0.5      0.622       0.56
#            diamond two        122          2          1        0.5       0.75      0.675
#          diamond three        122          2          1        0.5       0.75       0.75
#           diamond four        122          3          1      0.667      0.833      0.833
#           diamond five        122          1        0.5          1      0.995      0.895
#            diamond six        122          3          1          1      0.995      0.842
#          diamond seven        122          1        0.5          1      0.995      0.995
#          diamond eight        122          3          1          1      0.995      0.995
#            diamond ten        122          1          1          1      0.995      0.995
#         diamond knight        122          5          1        0.6        0.8      0.699
#          diamond queen        122          4          1       0.75      0.875      0.787
#           diamond king        122          2          1        0.5       0.75       0.75
#              spade ace        122          3          1      0.667      0.833      0.833
#              spade two        122          3          1      0.333      0.667      0.667
#            spade three        122          4      0.667          1      0.945      0.931
#             spade four        122          2      0.667          1      0.828      0.828
#             spade five        122          2          1        0.5       0.75       0.75
#              spade six        122          1          0          0          0          0
#            spade seven        122          3       0.75          1      0.913      0.896
#            spade eight        122          2          1        0.5       0.75       0.75
#             spade nine        122          2      0.667          1      0.995      0.995
#              spade ten        122          3      0.667      0.667      0.777      0.744
#             spade jack        122          1          1          1      0.995      0.995
#           spade knight        122          2          1        0.5       0.75        0.6
#            spade queen        122          2          1          1      0.995      0.895
#              heart ace        122          3      0.667      0.667      0.777      0.777
#              heart two        122          2          1        0.5       0.75       0.75
#            heart three        122          2          1        0.5       0.75      0.375
#             heart four        122          2          1          1      0.995      0.995
#              heart six        122          3      0.667      0.667      0.777      0.777
#            heart seven        122          4          1       0.75      0.875      0.749
#            heart eight        122          1          1          1      0.995      0.995
#              heart ten        122          2          1          1      0.995      0.995
#             heart jack        122          3          1          1      0.995      0.951
#           heart knight        122          4          1       0.75      0.875      0.758
#            heart queen        122          3          1      0.667      0.833        0.8
#             heart king        122          2          1        0.5       0.75       0.75
#               club ace        122          1          1          1      0.995      0.895
#               club two        122          1          0          0          0          0
#             club three        122          1          1          1      0.995      0.995
#              club four        122          2      0.667          1      0.995      0.995
#              club five        122          2          1          1      0.995      0.933
#               club six        122          4          1       0.75      0.875      0.875
#             club seven        122          2          1          1      0.995      0.995
#             club eight        122          1        0.5          1      0.995      0.995
#              club nine        122          3          1      0.333      0.667      0.667
#               club ten        122          2          1          1      0.995      0.958
#              club jack        122          4          1          1      0.995      0.933
#            club knight        122          2      0.667          1      0.995      0.995
#             club queen        122          2          0          0          0          0
#              club king        122          1          1          1      0.995      0.895
#              trump one        122          2          1        0.5       0.75      0.675
#              trump two        122          2      0.667          1      0.995      0.995
#            trump three        122          3          1          1      0.995      0.995
#             trump five        122          3          1      0.667      0.833      0.767
#              trump six        122          1        0.5          1      0.995      0.995
#            trump seven        122          2        0.5        0.5      0.622       0.56
#            trump eight        122          3      0.333      0.333      0.446      0.446
#             trump nine        122          5          1        0.4        0.7        0.7
#              trump ten        122          3          1          1      0.995      0.732
#           trump twelve        122          3          1      0.333      0.667        0.6
#         trump thirteen        122          1        0.5          1      0.995      0.995
#         trump fourteen        122          1          0          0          0          0
#          trump fifteen        122          4          1        0.5       0.75      0.718
#          trump sixteen        122          1          1          1      0.995      0.995
#        trump seventeen        122          3          1      0.667      0.833        0.8
#         trump eighteen        122          1          0          0          0          0
#           trump twenty        122          1          1          1      0.995      0.995
#        trump twentyone        122          3          1          1      0.995       0.94
#             trump fool        122          3          1          1      0.995       0.94
# Speed: 0.7ms preprocess, 8.0ms inference, 0.0ms loss, 8.0ms postprocess per image
# Results saved to runs/detect/val14

# %% [markdown]
# ## Track

# %%
# Load the YOLOv8 model
model = YOLO("./runs/detect/train6/weights/last.pt")

# Open the video file
video_path = "http://192.168.1.249:4747/video"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True, show=False)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Convert to tensorflow light app

# %%
model = YOLO("./runs/detect/train5/weights/last.pt")

# %%
model_onnx = model.export(format="onnx")

import onnx2tf

tf_model = onnx2tf.convert(model_onnx, output_tfv1_pb=True)
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.6 torch-2.2.1 CPU (Apple M3 Pro)
# Model summary (fused): 168 layers, 3134342 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'runs/detect/train5/weights/last.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 82, 8400) (36.5 MB)
#
# ONNX: starting export with onnx 1.16.0 opset 17...
# ONNX: export success ✅ 0.5s, saved as 'runs/detect/train5/weights/last.onnx' (12.2 MB)
#
# Export complete (0.7s)
# Results saved to /Users/stephane_branly/Documents/Projets/FrenchTarot/card-recognition-model/runs/detect/train5/weights
# Predict:         yolo predict task=detect model=runs/detect/train5/weights/last.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train5/weights/last.onnx imgsz=640 data=tarot_card_data.yaml
# Visualize:       https://netron.app

# %%
pip install onnx2tf --upgrade
import onnx2tf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: onnx2tf in /Users/stephane_branly/Library/Python/3.9/lib/python/site-packages (1.17.5)
# Collecting onnx2tf
#   Using cached onnx2tf-1.20.0-py3-none-any.whl.metadata (130 kB)
# Using cached onnx2tf-1.20.0-py3-none-any.whl (412 kB)
# WARNING: Error parsing requirements for keras: [Errno 2] No such file or directory: '/Users/stephane_branly/Library/Python/3.9/lib/python/site-packages/keras-3.1.1.dist-info/METADATA'
# Installing collected packages: onnx2tf
#   Attempting uninstall: onnx2tf
#     Found existing installation: onnx2tf 1.17.5
#     Uninstalling onnx2tf-1.17.5:
#       Successfully uninstalled onnx2tf-1.17.5
# Successfully installed onnx2tf-1.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
tf_model = onnx2tf.convert(model_onnx, output_tfv1_pb=True)
# Out:
# Model optimizing started ============================================================
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃            ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add        │ 9              │ 8                │
# │ Concat     │ 19             │ 19               │
# │ Constant   │ 149            │ 143              │
# │ Conv       │ 64             │ 64               │
# │ Div        │ 2              │ 1                │
# │ Gather     │ 1              │ 0                │
# │ MaxPool    │ 3              │ 3                │
# │ Mul        │ 60             │ 58               │
# │ Reshape    │ 5              │ 5                │
# │ Resize     │ 2              │ 2                │
# │ Shape      │ 1              │ 0                │
# │ Sigmoid    │ 58             │ 58               │
# │ Slice      │ 2              │ 2                │
# │ Softmax    │ 1              │ 1                │
# │ Split      │ 9              │ 9                │
# │ Sub        │ 2              │ 2                │
# │ Transpose  │ 1              │ 1                │
# │ Model Size │ 12.2MiB        │ 12.1MiB          │
# └────────────┴────────────────┴──────────────────┘
#
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃            ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add        │ 8              │ 8                │
# │ Concat     │ 19             │ 19               │
# │ Constant   │ 143            │ 143              │
# │ Conv       │ 64             │ 64               │
# │ Div        │ 1              │ 1                │
# │ MaxPool    │ 3              │ 3                │
# │ Mul        │ 58             │ 58               │
# │ Reshape    │ 5              │ 5                │
# │ Resize     │ 2              │ 2                │
# │ Sigmoid    │ 58             │ 58               │
# │ Slice      │ 2              │ 2                │
# │ Softmax    │ 1              │ 1                │
# │ Split      │ 9              │ 9                │
# │ Sub        │ 2              │ 2                │
# │ Transpose  │ 1              │ 1                │
# │ Model Size │ 12.1MiB        │ 12.1MiB          │
# └────────────┴────────────────┴──────────────────┘
#
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃            ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add        │ 8              │ 8                │
# │ Concat     │ 19             │ 19               │
# │ Constant   │ 143            │ 143              │
# │ Conv       │ 64             │ 64               │
# │ Div        │ 1              │ 1                │
# │ MaxPool    │ 3              │ 3                │
# │ Mul        │ 58             │ 58               │
# │ Reshape    │ 5              │ 5                │
# │ Resize     │ 2              │ 2                │
# │ Sigmoid    │ 58             │ 58               │
# │ Slice      │ 2              │ 2                │
# │ Softmax    │ 1              │ 1                │
# │ Split      │ 9              │ 9                │
# │ Sub        │ 2              │ 2                │
# │ Transpose  │ 1              │ 1                │
# │ Model Size │ 12.1MiB        │ 12.1MiB          │
# └────────────┴────────────────┴──────────────────┘
#
# Model optimizing complete!
#
# Automatic generation of each OP name started ========================================
# Automatic generation of each OP name complete!
#
# Model loaded ========================================================================
#
# Model conversion started ============================================================
# INFO: input_op_name: images shape: [1, 3, 640, 640] dtype: float32
# WARNING: The optimization process for shape estimation is skipped because it contains OPs that cannot be inferred by the standard onnxruntime.
# WARNING: [ONNXRuntimeError] : 2 : INVALID_ARGUMENT : Failed to load model with error: /Users/runner/work/1/s/onnxruntime/core/graph/model.cc:180 onnxruntime::Model::Model(ModelProto &&, const PathString &, const IOnnxRuntimeOpSchemaRegistryList *, const logging::Logger &, const ModelOptions &) Unsupported model IR version: 10, max supported IR version: 9
#
#
# INFO: 2 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.0/conv/Conv
# INFO:  input_name.1: images shape: [1, 3, 640, 640] dtype: float32
# INFO:  input_name.2: model.0.conv.weight shape: [16, 3, 3, 3] dtype: float32
# INFO:  input_name.3: model.0.conv.bias shape: [16] dtype: float32
# INFO:  output_name.1: wa/model.0/conv/Conv_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_14/Pad:0 shape: (1, 642, 642, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 3, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_142/Add:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
#
# INFO: 3 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.0/act/Sigmoid
# INFO:  input_name.1: wa/model.0/conv/Conv_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO:  output_name.1: wa/model.0/act/Sigmoid_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_142/Add:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_116/Sigmoid:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
#
# INFO: 4 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.0/act/Mul
# INFO:  input_name.1: wa/model.0/conv/Conv_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO:  input_name.2: wa/model.0/act/Sigmoid_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO:  output_name.1: wa/model.0/act/Mul_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_142/Add:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_116/Sigmoid:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_396/Mul:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
#
# INFO: 5 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.1/conv/Conv
# INFO:  input_name.1: wa/model.0/act/Mul_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO:  input_name.2: model.1.conv.weight shape: [32, 16, 3, 3] dtype: float32
# INFO:  input_name.3: model.1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_15/Pad:0 shape: (1, 322, 322, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_143/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 6 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.1/act/Sigmoid
# INFO:  input_name.1: wa/model.1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.1/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_143/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_117/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 7 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.1/act/Mul
# INFO:  input_name.1: wa/model.1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.1/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.1/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_143/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_117/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_399/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 8 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.2/cv1/conv/Conv
# INFO:  input_name.1: wa/model.1/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: model.2.cv1.conv.weight shape: [32, 32, 1, 1] dtype: float32
# INFO:  input_name.3: model.2.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.2/cv1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_399/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_144/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 9 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.2/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.2/cv1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/cv1/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_144/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_118/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 10 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.2/cv1/act/Mul
# INFO:  input_name.1: wa/model.2/cv1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.2/cv1/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/cv1/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_144/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_118/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_402/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 11 / 234
# INFO: onnx_op_type: Split onnx_op_name: wa/model.2/Split
# INFO:  input_name.1: wa/model.2/cv1/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: onnx::Split_137 shape: [2] dtype: int64
# INFO:  output_name.1: wa/model.2/Split_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.2: wa/model.2/Split_output_1 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.math.multiply_402/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (2,) dtype: int64
# INFO:  input.3.axis: val: 3
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.split/split:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.split/split:1 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 12 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.2/m.0/cv1/conv/Conv
# INFO:  input_name.1: wa/model.2/Split_output_1 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: model.2.m.0.cv1.conv.weight shape: [16, 16, 3, 3] dtype: float32
# INFO:  input_name.3: model.2.m.0.cv1.conv.bias shape: [16] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv1/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.split/split:1 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_145/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 13 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.2/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.2/m.0/cv1/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv1/act/Sigmoid_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_145/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_119/Sigmoid:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 14 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.2/m.0/cv1/act/Mul
# INFO:  input_name.1: wa/model.2/m.0/cv1/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.2/m.0/cv1/act/Sigmoid_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv1/act/Mul_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_145/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_119/Sigmoid:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_405/Mul:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 15 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.2/m.0/cv2/conv/Conv
# INFO:  input_name.1: wa/model.2/m.0/cv1/act/Mul_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: model.2.m.0.cv2.conv.weight shape: [16, 16, 3, 3] dtype: float32
# INFO:  input_name.3: model.2.m.0.cv2.conv.bias shape: [16] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv2/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_405/Mul:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_146/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 16 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.2/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.2/m.0/cv2/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv2/act/Sigmoid_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_146/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_120/Sigmoid:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 17 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.2/m.0/cv2/act/Mul
# INFO:  input_name.1: wa/model.2/m.0/cv2/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.2/m.0/cv2/act/Sigmoid_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/cv2/act/Mul_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_146/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_120/Sigmoid:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_408/Mul:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 18 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.2/m.0/Add
# INFO:  input_name.1: wa/model.2/Split_output_1 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.2/m.0/cv2/act/Mul_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/m.0/Add_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.split/split:1 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_408/Mul:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_147/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 19 / 234
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.2/Concat
# INFO:  input_name.1: wa/model.2/Split_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.2/Split_output_1 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.3: wa/model.2/m.0/Add_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/Concat_output_0 shape: [1, 48, 160, 160] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.split/split:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.split/split:1 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.input2: name: tf.math.add_147/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.4.axis: val: 3
# INFO:  output.1.output: name: tf.concat_36/concat:0 shape: (1, 160, 160, 48) dtype: <dtype: 'float32'>
#
# INFO: 20 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.2/cv2/conv/Conv
# INFO:  input_name.1: wa/model.2/Concat_output_0 shape: [1, 48, 160, 160] dtype: float32
# INFO:  input_name.2: model.2.cv2.conv.weight shape: [32, 48, 1, 1] dtype: float32
# INFO:  input_name.3: model.2.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.2/cv2/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat_36/concat:0 shape: (1, 160, 160, 48) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 48, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_148/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 21 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.2/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.2/cv2/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/cv2/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_148/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_121/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 22 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.2/cv2/act/Mul
# INFO:  input_name.1: wa/model.2/cv2/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: wa/model.2/cv2/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: wa/model.2/cv2/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_148/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_121/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_413/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 23 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.3/conv/Conv
# INFO:  input_name.1: wa/model.2/cv2/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: model.3.conv.weight shape: [64, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.3.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.3/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_16/Pad:0 shape: (1, 162, 162, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_149/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 24 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.3/act/Sigmoid
# INFO:  input_name.1: wa/model.3/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.3/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_149/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_122/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 25 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.3/act/Mul
# INFO:  input_name.1: wa/model.3/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.3/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.3/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_149/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_122/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_416/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 26 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/cv1/conv/Conv
# INFO:  input_name.1: wa/model.3/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.cv1.conv.weight shape: [64, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.4.cv1.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.4/cv1/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_416/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_150/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 27 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.4/cv1/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/cv1/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_150/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_123/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 28 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/cv1/act/Mul
# INFO:  input_name.1: wa/model.4/cv1/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/cv1/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/cv1/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_150/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_123/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_419/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 29 / 234
# INFO: onnx_op_type: Split onnx_op_name: wa/model.4/Split
# INFO:  input_name.1: wa/model.4/cv1/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Split_157 shape: [2] dtype: int64
# INFO:  output_name.1: wa/model.4/Split_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.2: wa/model.4/Split_output_1 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.math.multiply_419/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (2,) dtype: int64
# INFO:  input.3.axis: val: 3
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.split_1/split:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.split_1/split:1 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 30 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/m.0/cv1/conv/Conv
# INFO:  input_name.1: wa/model.4/Split_output_1 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.m.0.cv1.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.0.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.split_1/split:1 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_151/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 31 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.4/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv1/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_151/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_124/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 32 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/m.0/cv1/act/Mul
# INFO:  input_name.1: wa/model.4/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/m.0/cv1/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv1/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_151/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_124/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_422/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 33 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/m.0/cv2/conv/Conv
# INFO:  input_name.1: wa/model.4/m.0/cv1/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.m.0.cv2.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.0.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_422/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_152/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 34 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.4/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv2/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_152/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_125/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 35 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/m.0/cv2/act/Mul
# INFO:  input_name.1: wa/model.4/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/m.0/cv2/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/cv2/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_152/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_125/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_425/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 36 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.4/m.0/Add
# INFO:  input_name.1: wa/model.4/Split_output_1 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/m.0/cv2/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.0/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.split_1/split:1 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_425/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_153/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 37 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/m.1/cv1/conv/Conv
# INFO:  input_name.1: wa/model.4/m.0/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.m.1.cv1.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.1.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_153/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_154/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 38 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/m.1/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.4/m.1/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv1/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_154/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_126/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 39 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/m.1/cv1/act/Mul
# INFO:  input_name.1: wa/model.4/m.1/cv1/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/m.1/cv1/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv1/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_154/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_126/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_430/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 40 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/m.1/cv2/conv/Conv
# INFO:  input_name.1: wa/model.4/m.1/cv1/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.m.1.cv2.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.1.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_430/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_155/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 41 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/m.1/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.4/m.1/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv2/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_155/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_127/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 42 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/m.1/cv2/act/Mul
# INFO:  input_name.1: wa/model.4/m.1/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/m.1/cv2/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/cv2/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_155/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_127/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_433/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 43 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.4/m.1/Add
# INFO:  input_name.1: wa/model.4/m.0/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/m.1/cv2/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/m.1/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_153/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_433/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_156/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 44 / 234
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.4/Concat
# INFO:  input_name.1: wa/model.4/Split_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/Split_output_1 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.3: wa/model.4/m.0/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.4: wa/model.4/m.1/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/Concat_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.split_1/split:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.split_1/split:1 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.input2: name: tf.math.add_153/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.4.input3: name: tf.math.add_156/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.5.axis: val: 3
# INFO:  output.1.output: name: tf.concat_37/concat:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 45 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.4/cv2/conv/Conv
# INFO:  input_name.1: wa/model.4/Concat_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.cv2.conv.weight shape: [64, 128, 1, 1] dtype: float32
# INFO:  input_name.3: model.4.cv2.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.4/cv2/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat_37/concat:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_157/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 46 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.4/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.4/cv2/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/cv2/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_157/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_128/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 47 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.4/cv2/act/Mul
# INFO:  input_name.1: wa/model.4/cv2/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: wa/model.4/cv2/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: wa/model.4/cv2/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_157/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_128/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_438/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 48 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.5/conv/Conv
# INFO:  input_name.1: wa/model.4/cv2/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: model.5.conv.weight shape: [128, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.5.conv.bias shape: [128] dtype: float32
# INFO:  output_name.1: wa/model.5/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_17/Pad:0 shape: (1, 82, 82, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_158/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 49 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.5/act/Sigmoid
# INFO:  input_name.1: wa/model.5/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.5/act/Sigmoid_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_158/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_129/Sigmoid:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 50 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.5/act/Mul
# INFO:  input_name.1: wa/model.5/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.5/act/Sigmoid_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.5/act/Mul_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_158/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_129/Sigmoid:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_441/Mul:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 51 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/cv1/conv/Conv
# INFO:  input_name.1: wa/model.5/act/Mul_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.cv1.conv.weight shape: [128, 128, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.cv1.conv.bias shape: [128] dtype: float32
# INFO:  output_name.1: wa/model.6/cv1/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_441/Mul:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_159/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 52 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.6/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.6/cv1/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/cv1/act/Sigmoid_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_159/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_130/Sigmoid:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 53 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.6/cv1/act/Mul
# INFO:  input_name.1: wa/model.6/cv1/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.6/cv1/act/Sigmoid_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/cv1/act/Mul_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_159/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_130/Sigmoid:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_444/Mul:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 54 / 234
# INFO: onnx_op_type: Split onnx_op_name: wa/model.6/Split
# INFO:  input_name.1: wa/model.6/cv1/act/Mul_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  input_name.2: onnx::Split_184 shape: [2] dtype: int64
# INFO:  output_name.1: wa/model.6/Split_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.2: wa/model.6/Split_output_1 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.math.multiply_444/Mul:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (2,) dtype: int64
# INFO:  input.3.axis: val: 3
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.split_2/split:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.split_2/split:1 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 55 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/m.0/cv1/conv/Conv
# INFO:  input_name.1: wa/model.6/Split_output_1 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.m.0.cv1.conv.weight shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.0.cv1.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv1/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.split_2/split:1 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_160/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 56 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.6/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: wa/model.6/m.0/cv1/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv1/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_160/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_131/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 57 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.6/m.0/cv1/act/Mul
# INFO:  input_name.1: wa/model.6/m.0/cv1/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.6/m.0/cv1/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv1/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_160/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_131/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_447/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 58 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/m.0/cv2/conv/Conv
# INFO:  input_name.1: wa/model.6/m.0/cv1/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.m.0.cv2.conv.weight shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.0.cv2.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv2/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_447/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_161/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 59 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.6/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: wa/model.6/m.0/cv2/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv2/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_161/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_132/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 60 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.6/m.0/cv2/act/Mul
# INFO:  input_name.1: wa/model.6/m.0/cv2/conv/Conv_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.6/m.0/cv2/act/Sigmoid_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/cv2/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_161/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_132/Sigmoid:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_450/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 61 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.6/m.0/Add
# INFO:  input_name.1: wa/model.6/Split_output_1 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: wa/model.6/m.0/cv2/act/Mul_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.1: wa/model.6/m.0/Add_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.split_2/split:1 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_450/Mul:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_162/Add:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 62 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.6/m.1/cv1/conv/Conv
# ...
# INFO:  input_name.2: model.22.cv2.2.2.weight shape: [64, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.22.cv2.2.2.bias shape: [64] dtype: float32
# INFO:  output_name.1: wa/model.22/cv2.2/cv2.2.2/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_573/Mul:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_209/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
#
# INFO: 214 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.22/cv3.2/cv3.2.2/Conv
# INFO:  input_name.1: wa/model.22/cv3.2/cv3.2.1/act/Mul_output_0 shape: [1, 78, 20, 20] dtype: float32
# INFO:  input_name.2: model.22.cv3.2.2.weight shape: [78, 78, 1, 1] dtype: float32
# INFO:  input_name.3: model.22.cv3.2.2.bias shape: [78] dtype: float32
# INFO:  output_name.1: wa/model.22/cv3.2/cv3.2.2/Conv_output_0 shape: [1, 78, 20, 20] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_576/Mul:0 shape: (1, 20, 20, 78) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 78, 78) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (78,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_210/Add:0 shape: (1, 20, 20, 78) dtype: <dtype: 'float32'>
#
# INFO: 215 / 234
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.22/Concat_2
# INFO:  input_name.1: wa/model.22/cv2.2/cv2.2.2/Conv_output_0 shape: [1, 64, 20, 20] dtype: float32
# INFO:  input_name.2: wa/model.22/cv3.2/cv3.2.2/Conv_output_0 shape: [1, 78, 20, 20] dtype: float32
# INFO:  output_name.1: wa/model.22/Concat_2_output_0 shape: [1, 142, 20, 20] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.math.add_209/Add:0 shape: (1, 20, 20, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.math.add_210/Add:0 shape: (1, 20, 20, 78) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 3
# INFO:  output.1.output: name: tf.concat_51/concat:0 shape: (1, 20, 20, 142) dtype: <dtype: 'float32'>
#
# INFO: 216 / 234
# INFO: onnx_op_type: Reshape onnx_op_name: wa/model.22/Reshape_2
# INFO:  input_name.1: wa/model.22/Concat_2_output_0 shape: [1, 142, 20, 20] dtype: float32
# INFO:  input_name.2: wa/model.22/Constant_output_0 shape: (3,) dtype: int64
# INFO:  output_name.1: wa/model.22/Reshape_2_output_0 shape: [1, 142, 400] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_44/transpose:0 shape: (1, 142, 20, 20) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [1, 142, -1]
# INFO:  output.1.output: name: tf.reshape_12/Reshape:0 shape: (1, 142, 400) dtype: <dtype: 'float32'>
#
# INFO: 217 / 234
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.22/Concat_3
# INFO:  input_name.1: wa/model.22/Reshape_output_0 shape: [1, 142, 6400] dtype: float32
# INFO:  input_name.2: wa/model.22/Reshape_1_output_0 shape: [1, 142, 1600] dtype: float32
# INFO:  input_name.3: wa/model.22/Reshape_2_output_0 shape: [1, 142, 400] dtype: float32
# INFO:  output_name.1: wa/model.22/Concat_3_output_0 shape: [1, 142, 8400] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.reshape_10/Reshape:0 shape: (1, 142, 6400) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.reshape_11/Reshape:0 shape: (1, 142, 1600) dtype: <dtype: 'float32'>
# INFO:  input.3.input2: name: tf.reshape_12/Reshape:0 shape: (1, 142, 400) dtype: <dtype: 'float32'>
# INFO:  input.4.axis: val: 2
# INFO:  output.1.output: name: tf.concat_52/concat:0 shape: (1, 142, 8400) dtype: <dtype: 'float32'>
#
# INFO: 218 / 234
# INFO: onnx_op_type: Split onnx_op_name: wa/model.22/Split
# INFO:  input_name.1: wa/model.22/Concat_3_output_0 shape: [1, 142, 8400] dtype: float32
# INFO:  input_name.2: onnx::Split_388 shape: [2] dtype: int64
# INFO:  output_name.1: wa/model.22/Split_output_0 shape: [1, 64, 8400] dtype: float32
# INFO:  output_name.2: wa/model.22/Split_output_1 shape: [1, 78, 8400] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.concat_52/concat:0 shape: (1, 142, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (2,) dtype: int64
# INFO:  input.3.axis: val: 1
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.strided_slice_40/StridedSlice:0 shape: (1, 64, 8400) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.strided_slice_41/StridedSlice:0 shape: (1, 78, 8400) dtype: <dtype: 'float32'>
#
# INFO: 219 / 234
# INFO: onnx_op_type: Reshape onnx_op_name: wa/model.22/dfl/Reshape
# INFO:  input_name.1: wa/model.22/Split_output_0 shape: [1, 64, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/dfl/Constant_output_0 shape: [4] dtype: int64
# INFO:  output_name.1: wa/model.22/dfl/Reshape_output_0 shape: [1, 4, 16, 8400] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.strided_slice_40/StridedSlice:0 shape: (1, 64, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [1, 4, 16, 8400]
# INFO:  output.1.output: name: tf.reshape_13/Reshape:0 shape: (1, 4, 16, 8400) dtype: <dtype: 'float32'>
#
# INFO: 220 / 234
# INFO: onnx_op_type: Sigmoid onnx_op_name: wa/model.22/Sigmoid
# INFO:  input_name.1: wa/model.22/Split_output_1 shape: [1, 78, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/Sigmoid_output_0 shape: [1, 78, 8400] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.strided_slice_41/StridedSlice:0 shape: (1, 78, 8400) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_173/Sigmoid:0 shape: (1, 78, 8400) dtype: <dtype: 'float32'>
#
# INFO: 221 / 234
# INFO: onnx_op_type: Transpose onnx_op_name: wa/model.22/dfl/Transpose
# INFO:  input_name.1: wa/model.22/dfl/Reshape_output_0 shape: [1, 4, 16, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/dfl/Transpose_output_0 shape: [1, 16, 4, 8400] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.reshape_13/Reshape:0 shape: (1, 4, 16, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 2, 1, 3]
# INFO:  output.1.output: name: tf.compat.v1.transpose_47/transpose:0 shape: (1, 16, 4, 8400) dtype: <dtype: 'float32'>
#
# INFO: 222 / 234
# INFO: onnx_op_type: Softmax onnx_op_name: wa/model.22/dfl/Softmax
# INFO:  input_name.1: wa/model.22/dfl/Transpose_output_0 shape: [1, 16, 4, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/dfl/Softmax_output_0 shape: [1, 16, 4, 8400] dtype: float32
# INFO: tf_op_type: softmax_v2
# INFO:  input.1.logits: name: tf.compat.v1.transpose_48/transpose:0 shape: (1, 4, 8400, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.axis: val: 1
# INFO:  output.1.output: name: tf.compat.v1.transpose_49/transpose:0 shape: (1, 16, 4, 8400) dtype: <dtype: 'float32'>
#
# INFO: 223 / 234
# INFO: onnx_op_type: Conv onnx_op_name: wa/model.22/dfl/conv/Conv
# INFO:  input_name.1: wa/model.22/dfl/Softmax_output_0 shape: [1, 16, 4, 8400] dtype: float32
# INFO:  input_name.2: model.22.dfl.conv.weight shape: [1, 16, 1, 1] dtype: float32
# INFO:  output_name.1: wa/model.22/dfl/conv/Conv_output_0 shape: [1, 1, 4, 8400] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.transpose_50/transpose:0 shape: (1, 4, 8400, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 16, 1) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_191/convolution:0 shape: (1, 4, 8400, 1) dtype: <dtype: 'float32'>
#
# INFO: 224 / 234
# INFO: onnx_op_type: Reshape onnx_op_name: wa/model.22/dfl/Reshape_1
# INFO:  input_name.1: wa/model.22/dfl/conv/Conv_output_0 shape: [1, 1, 4, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/dfl/Constant_1_output_0 shape: [3] dtype: int64
# INFO:  output_name.1: wa/model.22/dfl/Reshape_1_output_0 shape: [1, 4, 8400] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: tf.compat.v1.transpose_53/transpose:0 shape: (1, 1, 4, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [1, 4, 8400]
# INFO:  output.1.output: name: tf.reshape_14/Reshape:0 shape: (1, 4, 8400) dtype: <dtype: 'float32'>
#
# INFO: 225 / 234
# INFO: onnx_op_type: Slice onnx_op_name: wa/model.22/Slice
# INFO:  input_name.1: wa/model.22/dfl/Reshape_1_output_0 shape: [1, 4, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Constant_4_output_0 shape: [1] dtype: int64
# INFO:  input_name.3: wa/model.22/Div_output_0 shape: [1] dtype: int64
# INFO:  input_name.4: wa/model.22/Constant_3_output_0 shape: [1] dtype: int64
# INFO:  output_name.1: wa/model.22/Slice_output_0 shape: [1, 2, 8400] dtype: float32
# INFO: tf_op_type: strided_slice
# INFO:  input.1.input_: name: tf.reshape_14/Reshape:0 shape: (1, 4, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.begin: shape: (1,) dtype: int64
# INFO:  input.3.end: shape: (1,) dtype: int64
# INFO:  input.4.strides:
# INFO:  output.1.output: name: tf.strided_slice_42/StridedSlice:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
#
# INFO: 226 / 234
# INFO: onnx_op_type: Slice onnx_op_name: wa/model.22/Slice_1
# INFO:  input_name.1: wa/model.22/dfl/Reshape_1_output_0 shape: [1, 4, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Div_output_0 shape: (1,) dtype: int64
# INFO:  input_name.3: wa/model.22/Mul_1_output_0 shape: [1] dtype: int64
# INFO:  input_name.4: wa/model.22/Constant_3_output_0 shape: (1,) dtype: int64
# INFO:  output_name.1: wa/model.22/Slice_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO: tf_op_type: strided_slice
# INFO:  input.1.input_: name: tf.reshape_14/Reshape:0 shape: (1, 4, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.begin: shape: (1,) dtype: int64
# INFO:  input.3.end: shape: (1,) dtype: int64
# INFO:  input.4.strides:
# INFO:  output.1.output: name: tf.strided_slice_43/StridedSlice:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
#
# INFO: 227 / 234
# INFO: onnx_op_type: Sub onnx_op_name: wa/model.22/Sub
# INFO:  input_name.1: wa/model.22/Constant_9_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Slice_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/Sub_output_0 shape: [1, 2, 8400] dtype: float32
# INFO: tf_op_type: subtract
# INFO:  input.1.x: shape: (1, 2, 8400) dtype: float32
# INFO:  input.2.y: name: tf.strided_slice_42/StridedSlice:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.subtract_4/Sub:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
#
# INFO: 228 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.22/Add_1
# INFO:  input_name.1: wa/model.22/Constant_9_output_0 shape: (1, 2, 8400) dtype: float32
# INFO:  input_name.2: wa/model.22/Slice_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/Add_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: shape: (1, 2, 8400) dtype: float32
# INFO:  input.2.y: name: tf.strided_slice_43/StridedSlice:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_211/Add:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
#
# INFO: 229 / 234
# INFO: onnx_op_type: Add onnx_op_name: wa/model.22/Add_2
# INFO:  input_name.1: wa/model.22/Sub_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Add_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/Add_2_output_0 shape: [1, 2, 8400] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.subtract_4/Sub:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.add_211/Add:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_212/Add:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
#
# INFO: 230 / 234
# INFO: onnx_op_type: Sub onnx_op_name: wa/model.22/Sub_1
# INFO:  input_name.1: wa/model.22/Add_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Sub_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/Sub_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO: tf_op_type: subtract
# INFO:  input.1.x: name: tf.math.add_211/Add:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.subtract_4/Sub:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.subtract_5/Sub:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
#
# INFO: 231 / 234
# INFO: onnx_op_type: Div onnx_op_name: wa/model.22/Div_1
# INFO:  input_name.1: wa/model.22/Add_2_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Constant_11_output_0 shape: [] dtype: float32
# INFO:  output_name.1: wa/model.22/Div_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO: tf_op_type: divide
# INFO:  input.1.x: name: tf.math.add_212/Add:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.divide_2/truediv:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
#
# INFO: 232 / 234
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.22/Concat_4
# INFO:  input_name.1: wa/model.22/Div_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Sub_1_output_0 shape: [1, 2, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/Concat_4_output_0 shape: [1, 4, 8400] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.math.divide_2/truediv:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.math.subtract_5/Sub:0 shape: (1, 2, 8400) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 1
# INFO:  output.1.output: name: tf.concat_53/concat:0 shape: (1, 4, 8400) dtype: <dtype: 'float32'>
#
# INFO: 233 / 234
# INFO: onnx_op_type: Mul onnx_op_name: wa/model.22/Mul_2
# INFO:  input_name.1: wa/model.22/Concat_4_output_0 shape: [1, 4, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Constant_12_output_0 shape: [1, 8400] dtype: float32
# INFO:  output_name.1: wa/model.22/Mul_2_output_0 shape: [1, 4, 8400] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.concat_53/concat:0 shape: (1, 4, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 8400) dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_589/Mul:0 shape: (1, 4, 8400) dtype: <dtype: 'float32'>
#
# INFO: 234 / 234
# INFO: onnx_op_type: Concat onnx_op_name: wa/model.22/Concat_5
# INFO:  input_name.1: wa/model.22/Mul_2_output_0 shape: [1, 4, 8400] dtype: float32
# INFO:  input_name.2: wa/model.22/Sigmoid_output_0 shape: [1, 78, 8400] dtype: float32
# INFO:  output_name.1: output0 shape: [1, 82, 8400] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.math.multiply_589/Mul:0 shape: (1, 4, 8400) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.math.sigmoid_173/Sigmoid:0 shape: (1, 78, 8400) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 1
# INFO:  output.1.output: name: tf.concat_54/concat:0 shape: (1, 82, 8400) dtype: <dtype: 'float32'>
#
# saved_model output started ==========================================================
# saved_model output complete!
# TFv1 v1 .pb output started ==========================================================
# TFv1 .pb output complete!
# W0000 00:00:1713384140.239950 2133528 tf_tfl_flatbuffer_helpers.cc:390] Ignored output_format.
# W0000 00:00:1713384140.239959 2133528 tf_tfl_flatbuffer_helpers.cc:393] Ignored drop_control_dependency.
# Float32 tflite output complete!
# Float16 tflite output complete!
# W0000 00:00:1713384140.665673 2133528 tf_tfl_flatbuffer_helpers.cc:390] Ignored output_format.
# W0000 00:00:1713384140.665683 2133528 tf_tfl_flatbuffer_helpers.cc:393] Ignored drop_control_dependency.
